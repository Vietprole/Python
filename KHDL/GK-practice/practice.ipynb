# %% [markdown]
# ### Bài 1

# %%
class Rectangle:
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def calculate_area(self):
        return self.length * self.width

    def calculate_perimeter(self):
        return 2 * (self.length + self.width)

    def is_square(self):
        return self.length == self.width

length = float(input("Enter the length of the rectangle: "))
width = float(input("Enter the width of the rectangle: "))

rectangle = Rectangle(length, width)
area = rectangle.calculate_area()
perimeter = rectangle.calculate_perimeter()
is_square = rectangle.is_square()

print("Area:", area)
print("Perimeter:", perimeter)
print("Is square?", is_square)
# Out:
# Area: 120.0
# Perimeter: 44.0
# Is square? False

# %% [markdown]
# ### Bài 2

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function
def F(x):
    return (5-x-4*x**2)*np.exp((3*x**3+x**2+x)/(x-3))
print(F(0))
# Generate x values
x = np.linspace(-5, 5, 100)

# Generate y values
y = F(x)

# Plot the function
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('F(x)')
plt.title('Plot of F(x)')
plt.grid(True)
plt.ylim(-10,10)
plt.show()
# Out:
# 5.0
# C:\Users\OS\AppData\Local\Temp\ipykernel_18164\1556358399.py:6: RuntimeWarning: overflow encountered in exp
#   return (5-x-4*x**2)*np.exp((3*x**3+x**2+x)/(x-3))

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the function
def F(x, y):
    return (2*x**2 + 2*y**2 + x*y)/(x**3-1)

# Generate x and y values
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)

# Generate z values
Z = F(X, Y)

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z)

# Set labels and title
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('F(x, y)')
ax.set_title('3D Plot of F(x, y)')

# Show the plot
plt.show()
