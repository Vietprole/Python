# %%
import pandas as pd 

# df = pd.read_csv(r'G:\My Drive\0. Day ben ngoai (___)\Day Cole\Khoa ML for invesment - Thanhdt (11.2023)\Buổi 2. Python basic\data.csv') # File hay load tu DB hay load tu API san
df = pd.read_csv('data/data.csv')
df
# Out:
#       Datetime     Open     High      Low    Close   Volume      SMA  \
# 0   2023-09-05  89100.0  90700.0  89100.0  90100.0  2013202      NaN
# 1   2023-09-06  90200.0  90200.0  89700.0  90200.0  2057603      NaN
# 2   2023-09-07  90000.0  90800.0  89500.0  89500.0  1958302      NaN
# 3   2023-09-08  89500.0  89500.0  89100.0  89500.0  1381905      NaN
# 4   2023-09-11  89600.0  90000.0  88000.0  88500.0  2592500      NaN
# ..         ...      ...      ...      ...      ...      ...      ...
# 75  2023-12-20  81200.0  81300.0  80500.0  81100.0  2014300  84510.0
# 76  2023-12-21  81000.0  81000.0  80300.0  80900.0  2148400  84220.0
# 77  2023-12-22  80900.0  81100.0  80400.0  80900.0  1721800  83990.0
# 78  2023-12-25  80900.0  81800.0  80700.0  81800.0  1480000  83780.0
# 79  2023-12-26  82000.0  82800.0  82000.0  82800.0  1113200  83630.0
#
#        short_ema      long_ema         MACD  Signal_Line  Buy_Signal  \
# ...

# %%
df.head(10)
# Out:
#      Datetime     Open     High      Low    Close   Volume  SMA     short_ema  \
# 0  2023-09-05  89100.0  90700.0  89100.0  90100.0  2013202  NaN  90100.000000
# 1  2023-09-06  90200.0  90200.0  89700.0  90200.0  2057603  NaN  90115.384615
# 2  2023-09-07  90000.0  90800.0  89500.0  89500.0  1958302  NaN  90020.710059
# 3  2023-09-08  89500.0  89500.0  89100.0  89500.0  1381905  NaN  89940.600819
# 4  2023-09-11  89600.0  90000.0  88000.0  88500.0  2592500  NaN  89718.969924
# 5  2023-09-12  89000.0  90000.0  88900.0  89900.0  1612100  NaN  89746.820705
# 6  2023-09-13  90000.0  90000.0  88900.0  89100.0  1675000  NaN  89647.309827
# 7  2023-09-14  89000.0  89500.0  88100.0  89100.0  1552600  NaN  89563.108315
# 8  2023-09-15  88900.0  89800.0  88600.0  89800.0  2235400  NaN  89599.553190
# 9  2023-09-18  89500.0  89700.0  88300.0  88800.0   789102  NaN  89476.545007
#
#        long_ema        MACD  Signal_Line  Buy_Signal  Sell_Signal
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Datetime     80 non-null     object
#  1   Open         80 non-null     float64
#  2   High         80 non-null     float64
#  3   Low          80 non-null     float64
#  4   Close        80 non-null     float64
#  5   Volume       80 non-null     int64
#  6   SMA          61 non-null     float64
#  7   short_ema    80 non-null     float64
#  8   long_ema     80 non-null     float64
#  9   MACD         80 non-null     float64
#  10  Signal_Line  80 non-null     float64
#  11  Buy_Signal   80 non-null     bool
#  12  Sell_Signal  80 non-null     bool
# dtypes: bool(2), float64(9), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.describe()
# Out:
#                Open          High           Low         Close        Volume  \
# count     80.000000     80.000000     80.000000     80.000000  8.000000e+01
# mean   86233.750000  86810.000000  85417.500000  86250.000000  1.409296e+06
# std     2269.218555   2317.823073   2239.731844   2293.579371  6.960302e+05
# min    80900.000000  81000.000000  80100.000000  80900.000000  4.884000e+05
# 25%    85075.000000  85875.000000  84100.000000  85000.000000  9.199500e+05
# 50%    86000.000000  86550.000000  85450.000000  86000.000000  1.211152e+06
# 75%    88000.000000  89000.000000  86725.000000  88000.000000  1.700200e+06
# max    90200.000000  90800.000000  89700.000000  90200.000000  4.172800e+06
#
#                 SMA     short_ema      long_ema         MACD  Signal_Line
# count     61.000000     80.000000     80.000000    80.000000    80.000000
# mean   86353.442623  86772.039896  87242.933651  -470.893755  -414.509397
# ...

# %%
df['Volume'] # Cot Volume
# Out:
# 0     2013202
# 1     2057603
# 2     1958302
# 3     1381905
# 4     2592500
#        ...
# 75    2014300
# 76    2148400
# 77    1721800
# 78    1480000
# 79    1113200
# Name: Volume, Length: 80, dtype: int64

# %%
df.iloc[4] # Hang index 4
# Out:
# Datetime         2023-09-11
# Open                89600.0
# High                90000.0
# Low                 88000.0
# Close               88500.0
# Volume              2592500
# SMA                     NaN
# short_ema      89718.969924
# long_ema       89908.105509
# MACD            -189.135585
# Signal_Line       -55.17289
# Buy_Signal            False
# Sell_Signal           False
# Name: 4, dtype: object

# %%
df['Cot 14'] = 14

df
# Out:
#       Datetime     Open     High      Low    Close   Volume      SMA  \
# 0   2023-09-05  89100.0  90700.0  89100.0  90100.0  2013202      NaN
# 1   2023-09-06  90200.0  90200.0  89700.0  90200.0  2057603      NaN
# 2   2023-09-07  90000.0  90800.0  89500.0  89500.0  1958302      NaN
# 3   2023-09-08  89500.0  89500.0  89100.0  89500.0  1381905      NaN
# 4   2023-09-11  89600.0  90000.0  88000.0  88500.0  2592500      NaN
# ..         ...      ...      ...      ...      ...      ...      ...
# 75  2023-12-20  81200.0  81300.0  80500.0  81100.0  2014300  84510.0
# 76  2023-12-21  81000.0  81000.0  80300.0  80900.0  2148400  84220.0
# 77  2023-12-22  80900.0  81100.0  80400.0  80900.0  1721800  83990.0
# 78  2023-12-25  80900.0  81800.0  80700.0  81800.0  1480000  83780.0
# 79  2023-12-26  82000.0  82800.0  82000.0  82800.0  1113200  83630.0
#
#        short_ema      long_ema         MACD  Signal_Line  Buy_Signal  \
# ...
